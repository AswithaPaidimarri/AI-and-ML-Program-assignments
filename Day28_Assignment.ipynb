# %% [markdown]
# # **AI and ML Program by letsUpgrade**
# # **DAY 28 ASSIGNMENT**
# # **SUBMITTED BY**
# # **NAME:-PAIDIMARRI VENKATA SAI ASWITHA**

# %% [markdown]
# # **Question 1:**

# %% [markdown]
# #Create one array of actual values and another array of predicted values. Compare the two sets with the confusion matrix.

# %%
from sklearn.metrics import confusion_matrix
actual=[1,0,0,1,0,1,0,0,0,0,1,0]
predicted=[1,1,0,0,0,1,0,0,0,1,1,0]
matrix=confusion_matrix(actual,predicted,labels=[1,0])
print("confusion matrix: \n",matrix)
tp,fn,fp,tn=confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)
# Out:
# confusion matrix:
#  [[3 1]
#  [2 6]]
# Outcome values :
#  3 1 2 6

# %% [markdown]
# # **Question 2:**

# %% [markdown]
# # **Find out the recall, precision, F1 score and confusion matrix with picture**
# ![image.png](data:image/png;base64,...)

# %%
TP=42
FN=18
FP=8
TN=32
Accuracy = (TP + TN)/(TP + TN + FP + FN)
print(Accuracy)
# Out:
# 0.74

# %% [markdown]
# # **precision**

# %%
precision=TP/(TP+FP)
print(precision)
# Out:
# 0.84

# %% [markdown]
# # **Recall**

# %%
recall=TP/(TP+FN)
print(recall)
# Out:
# 0.7

# %% [markdown]
# # **F1 Score**

# %%
f1_score = 2 * precision * recall / (precision + recall)
print(f1_score)
# Out:
# 0.9310344827586207
