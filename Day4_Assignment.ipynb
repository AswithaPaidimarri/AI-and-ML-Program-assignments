# %% [markdown]
# # **AI and ML Program by letsUpgrade**
# # **DAY4 ASSIGNMENT**
# # **SUBMITTED BY**
# # **NAME:-PAIDIMARRI VENKATA SAI ASWITHA**

# %% [markdown]
# # **Question1**
# Research on whether addition, subtraction, multiplication, division, floor division, and modulo operations
# be performed on complex numbers. Based on your study, implement a Python program to demonstrate
# these operations.

# %%
#We can perform addition,subtraction,multiplication,division on complex numbers but we can't perform floor division and modulo operation on complex numbers.
a=2+3j
b=3+2j
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# (5+5j)
# (-1+1j)
# 13j
# (0.9230769230769231+0.38461538461538464j)

# %% [markdown]
# # **Question2**
# Research on range() functions and its parameters. Create a markdown cell and write in your own words
# (no copy-paste from google please) what you understand about it. Implement a small program of your
# choice on the same.

# %% [markdown]
#  **ANSWER**:-The range() function gives sequence of numbers,starting from 0 by default and increments by 1 default and stops before a specified number.When we mention stepsize in this function then sequence of numbers generated by increment with stepsize value.

# %%
for i in range(1,9):
  print(i,end=" ")
# Out:
# 1 2 3 4 5 6 7 8

# %% [markdown]
# # **Question3**
# Consider two numbers. Perform their subtraction and if the result of subtraction is greater than 25, print
# their multiplication result else print their division result.

# %%
a=40
b=10
res=a-b
if res>25:
  print(a*b)
else:
  print(a/b)
# Out:
# 400

# %% [markdown]
# # **Question4**
# Consider a list of 10 elements of integer values. If the number in the list is divisible by 2, print the result as
# "square of that number minus 2".

# %%
l=[1,2,4,7,9,10,3,6,5,8]
for i in range(len(l)):
  if l[i]%2==0:
    print(l[i],"-","square of that number minus 2")
# Out:
# 2 - square of that number minus 2
# 4 - square of that number minus 2
# 10 - square of that number minus 2
# 6 - square of that number minus 2
# 8 - square of that number minus 2

# %% [markdown]
# # **Question5**
# Consider a list of 10 elements. Print all the elements in the list which are greater than 7 when that number is divided 2.

# %%
l=[12,2,14,7,19,10,3,6,5,8]
for i in range(len(l)):
  if l[i]>7 and l[i]%2==0:
    print(l[i],end=" ")
# Out:
# 12 14 10 8
